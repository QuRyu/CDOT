# %% [markdown]
# ### Data Pre-processing

# %%
import pandas as pd 

data = pd.read_excel('./PerlCOdownload.xls')
data.head(5)
# Out:
#      Contract ID  Bid Rank Vendor ID                        Vendor Name  \
# 0         C11328         0     -EST-                ENGINEER'S ESTIMATE
# 1         C11328         1      090A    INTERSTATE HIGHWAY CONSTRUCTION
# 2         C11328         2      822B  ACME MATERIALS & CONSTRUCTION CO.
# 3         C11328         3      150B   CASTLE ROCK CONSTRUCTION COMPANY
# 4         C11328         4      854A            LAWSON CONSTRUCTION CO.
# ...          ...       ...       ...                                ...
# 6592      C14626         2     S2881               PREMIER PAVING, INC.
# 6593      C14626         3      017A                 ASPHALT PAVING CO.
# 6594      C14626         4      924A      ASPHALT SPECIALTIES CO., INC.
# 6595      C14626         5      028B   AGGREGATE INDUSTRIES - WCR, INC.
# 6596      C14626         6      159C                 KIEWIT WESTERN CO.
#
#         Total Bid  % of Low Bid % of Engineer's Estimate  ParticipantsCount
# 0     1.50331e+07      0.914889                        1                  4
# 1     1.64316e+07      1.000000                  1.09303                  4
# 2     1.77401e+07      1.079631                  1.18007                  4
# 3     1.80151e+07      1.096367                  1.19836                  4
# 4      2.0288e+07      1.234690                  1.34955                  4
# ...           ...           ...                      ...                ...
# 6592       759908      1.008451                 0.993719                  6
# 6593       829408      1.100683                   1.0846                  6
# 6594       838388      1.112599                  1.09635                  6
# 6595       922818      1.224644                  1.20676                  6
# 6596  1.01482e+06      1.346741                  1.32707                  6
#
# [6597 rows x 8 columns]

# %%
# drop EST rows
data = data[data['Vendor ID'] != '-EST-']


# For auctions with n >= 2 bidders, if the number of rows for n-bidder auctions is not larger than 32,
# then remove all such data
N = 32

participants_numbers = pd.unique(data['ParticipantsCount'])
to_keep = [] 
for i in participants_numbers:
    if len(data[data['ParticipantsCount'] == i]) >= N:
        to_keep.append(i)

        
# remove auctions with one bidder 
if 1 in to_keep:
    to_keep.remove(1)
        
data = data[data['ParticipantsCount'].isin(to_keep)]


# rename and drop some columns 
data.rename(columns={"% of Engineer's Estimate": 'PercentOfEstimates'}, inplace=True)
data.drop(columns=['Vendor Name', 'Total Bid', '% of Low Bid'], inplace=True)


data.head(5)
# Out:
#    Contract ID  Bid Rank Vendor ID  \
# 1       C11328         1      090A
# 2       C11328         2      822B
# 3       C11328         3      150B
# 4       C11328         4      854A
# 6       C11434         1      084A
# 7       C11434         2      250A
# 8       C11434         3      053D
# 9       C11434         4      797A
# 11      C91094         1      163E
# 12      C91094         2      311A
# 13      C91094         3      924A
# 14      C91094         4      884A
# 15      C91094         5      696A
# 16      C91094         6      159C
# 17      C91094         7      028B
#
#                                        Vendor Name    Total Bid  % of Low Bid  \
# 1                  INTERSTATE HIGHWAY CONSTRUCTION  1.64316e+07      1.000000
# 2                ACME MATERIALS & CONSTRUCTION CO.  1.77401e+07      1.079631
# 3                 CASTLE ROCK CONSTRUCTION COMPANY  1.80151e+07      1.096367
# 4                          LAWSON CONSTRUCTION CO.   2.0288e+07      1.234690
# 6                DUCKELS CONSTRUCTION INCORPORATED       574864      1.000000
# 7                     SCHMUESER & ASSOCIATES, INC.       593386      1.032220
# 8    HELM GROUP, INC. dba CIVIL CONSTRUCTORS, INC.       593831      1.032994
# 9                          NATIVE EXCAVATING, INC.       613023      1.066379
# 11  WESTERN MOBILE, INC. dba WESTERN MOBILE DENVER  2.86095e+06      1.000000
# 12                      WYCON CONSTRUCTION COMPANY  3.01336e+06      1.053271
# 13                   ASPHALT SPECIALTIES CO., INC.  3.07096e+06      1.073404
# 14                         HAMON CONTRACTORS, INC.  3.19307e+06      1.116085
# 15                     JALISCO INTERNATIONAL, INC.  3.19596e+06      1.117098
# 16                              KIEWIT WESTERN CO.  3.28621e+06      1.148642
# 17               CAMAS inc dba BITUMINOUS ROADWAYS  3.47203e+06      1.213593
#
#    % of Engineer's Estimate  ParticipantsCount
# 1                   1.09303                  4
# 2                   1.18007                  4
# 3                   1.19836                  4
# 4                   1.34955                  4
# 6                  0.951778                  4
# 7                  0.982445                  4
# 8                  0.983181                  4
# 9                   1.01496                  4
# 11                 0.960044                  8
# 12                  1.01119                  8
# 13                  1.03052                  8
# 14                  1.07149                  8
# 15                  1.07246                  8
# 16                  1.10275                  8
# 17                   1.1651                  8

# %%
# clean data in PerecentOfEstimates column

# data = data.reset_index(drop=True)
# estimates = data['PercentOfEstimates'].tolist()
# estimates_cleaned = [] 

# non_str_count = 0
# str_count = 0
# for x in estimates:
#     if type(x) is not str:
#         non_str_count += 1
#         estimates_cleaned.append(x * 100)
#     else:
#         str_count += 1
#         values = [] 
#         for i in x.split():
#             values.append(float(i.replace('%', '').replace('\"', '')))
        
#         estimates_cleaned.append(min(values))
    
# data['PercentOfEstimates'] = pd.Series(estimates_cleaned)

# %%
# save the data

data.to_csv('DataProcessed.csv')
